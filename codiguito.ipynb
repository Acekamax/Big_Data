# %% [markdown]
# <a href="https://colab.research.google.com/github/Acekamax/Big_Data/blob/daniel/codiguito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.loc[0:10,"Age"]
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# Name: Age, dtype: float64

# %%
df.iloc[0:10,3:5]
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
df[(df["Age"]<20) & (df["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass  ...      Fare        Cabin  Embarked
# 7              8         0       3  ...   21.0750          NaN         S
# 16            17         0       3  ...   29.1250          NaN         Q
# 27            28         0       1  ...  263.0000  C23 C25 C27         S
# 50            51         0       3  ...   39.6875          NaN         S
# 59            60         0       3  ...   46.9000          NaN         S
# ..           ...       ...     ...  ...       ...          ...       ...
# 841          842         0       2  ...   10.5000          NaN         S
# 844          845         0       3  ...    8.6625          NaN         S
# 850          851         0       3  ...   31.2750          NaN         S
# 869          870         1       3  ...   11.1333          NaN         S
# 877          878         0       3  ...    7.8958          NaN         S
#
# [89 rows x 12 columns]

# %%
df[(df["Age"]<10) & (df["Survived"]==1)].count()
# Out:
# PassengerId    38
# Survived       38
# Pclass         38
# Name           38
# Sex            38
# Age            38
# SibSp          38
# Parch          38
# Ticket         38
# Fare           38
# Cabin           8
# Embarked       38
# dtype: int64

# %%
df["Sex2"]=df["Sex"].map({"female":1, "male":0})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Sex2
# 0              1         0       3  ...   NaN        S     0
# 1              2         1       1  ...   C85        C     1
# 2              3         1       3  ...   NaN        S     1
# 3              4         1       1  ...  C123        S     1
# 4              5         0       3  ...   NaN        S     0
# ..           ...       ...     ...  ...   ...      ...   ...
# 886          887         0       2  ...   NaN        S     0
# 887          888         1       1  ...   B42        S     1
# 888          889         0       3  ...   NaN        S     1
# 889          890         1       1  ...  C148        C     0
# 890          891         0       3  ...   NaN        Q     0
#
# [891 rows x 13 columns]

# %%
pd.get_dummies(df["Sex"])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
pd.get_dummies(df["Embarked"])
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
df["Embarked"].map({"C":0,"Q":1,"S":2})
# Out:
# 0      2.0
# 1      0.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 886    2.0
# 887    2.0
# 888    2.0
# 889    0.0
# 890    1.0
# Name: Embarked, Length: 891, dtype: float64

# %%
df["Age"].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
import pandas as pd
df = pd.read_csv("/content/titanic.csv")
def function(x):
  if x=='Braund':
    df["Age"].describe()
  else:
    print("no hay nada")  

x="Braund"
function(x)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-eac008b317eb> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("/content/titanic.csv")
#       3 def function(x):
#       4   if x=='Braund':
#       5     df["Age"].describe()
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
